# %%
import pickle
import numpy as np
from matplotlib import pyplot as plt

# %%
with open('trajectories.pyo', 'rb') as f:
    fo = pickle.load(f)
    y_vec = fo['y_vec']
    t_vec = fo['t_vec']

# %%
y_vec = np.array(y_vec)

# %%
v_vec = np.diff(y_vec, axis=1)

# %%
for i in range(5):
    plt.figure()
    plt.plot(v_vec[i,])
