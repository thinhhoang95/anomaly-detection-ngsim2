# %% [markdown]
# # Some miscellaneous results for the paper
#
# Mostly includes the illustrations in the paper

# %% [markdown]
# ## Bayes Factor Illustration

# %%
import numpy as np
from scipy.stats import multivariate_normal
from matplotlib import pyplot as plt

# %%
x, y = np.mgrid[-1:1:.01, -1:1:.01]
pos = np.dstack((x, y))
rv = multivariate_normal([0.5, -0.2], [[2.0, 0.3], [0.3, 0.5]])
plt.contourf(x, y, rv.pdf(pos))
plt.xlim((-1,1))
plt.ylim((-1,1))
# Out:
# (-1.0, 1.0)

# %%
x, y = np.mgrid[-1:1:.01, -1:1:.01]
pos = np.dstack((x, y))
rv = multivariate_normal([-0.5, 0.2], [[2.0, 0.3], [0.3, 0.5]])
plt.contourf(x, y, rv.pdf(pos))
plt.xlim((-1,1))
plt.ylim((-1,1))
# Out:
# (-1.0, 1.0)

# %%
x, y = np.mgrid[-1:1:.01, -1:1:.01]
pos = np.dstack((x, y))
rv = multivariate_normal([0, 0], [[2.0, 0.3], [0.3, 0.5]])
plt.contourf(x, y, rv.pdf(pos))
plt.xlim((-1,1))
plt.ylim((-1,1))
# Out:
# (-1.0, 1.0)

# %%
x, y = np.mgrid[-1:1:.01, -1:1:.01]
pos = np.dstack((x, y))
rv = multivariate_normal([0, 0], [[1, 0], [0, 1]])
plt.contourf(x, y, rv.pdf(pos))
plt.xlim((-1,1))
plt.ylim((-1,1))
# Out:
# (-1.0, 1.0)
