# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('kalmaned2.csv')
df['Global_Time'] = df['Global_Time'] - df['Global_Time'].min()
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Vehicle_ID  Frame_ID  Total_Frames  Global_Time  \
# 0           0             0           1       270           569        26000
# 1           1             1           1       271           569        26100
# 2           2             2           1       272           569        26200
# 3           3             3           1       273           569        26300
# 4           4             4           1       274           569        26400
#
#    Local_X  Local_Y     Global_X     Global_Y  ...  v_Vel  v_Acc  Lane_ID  \
# 0   51.164  112.878  6451136.708  1873294.084  ...  19.89   0.00        5
# 1   51.153  114.878  6451138.053  1873292.603  ...  19.89   0.00        5
# 2   51.143  116.878  6451139.397  1873291.122  ...  19.89   0.00        5
# 3   51.244  118.815  6451140.617  1873289.614  ...  19.89   0.00        5
# 4   51.234  120.814  6451141.961  1873288.133  ...  19.89   1.07        5
#
# ...

# %%
veh_665 = df[(df['Vehicle_ID'] == 665) & (df['Local_Y'] > 517)]['Local_Y'].to_numpy()
veh_658 = df[(df['Vehicle_ID'] == 658) & (df['Local_Y'] > 579)]['Local_Y'].to_numpy()

# %%
plt.plot(veh_665)
plt.plot(veh_658)
