# %% [markdown]
# # Finding a good basis for lateral coordinate
#
# I suppose wavelets may have something to do with this.

# %% [markdown]
# ## Load the trajectory data, as usual

# %%
import numpy as np
import pickle 
from matplotlib import pyplot as plt 
trajectory_file = open("trajectories.pyo", "rb")
trajs = pickle.load(trajectory_file)
x_vec = np.array(trajs['x_vec'])
y_vec = np.array(trajs['y_vec'])
t_vec = np.array(trajs['t_vec'])
del trajs
trajectory_file.close()
del trajectory_file

# %%
for traj in range(x_vec.shape[0]):
    plt.plot(x_vec[traj])

# %%
for traj in range(y_vec.shape[0]):
    plt.plot(y_vec[traj])
